# %% [markdown]
#                                                      -Ariveeti Karthikeya Reddy
#                                                      mailid:-karthikeya9503@gmail.com
# *   To find Memory Utilization among ML libraries we can use a module named **'tracemalloc'** and RAM usage using module **'psutil'** and execution time using module **'time'**
#
# *   tracemalloc.get_traced_memory() return in form of tuple(current,peak)
#
# *   current--> current memory the code is using currently ,
# peak--> peak memory the code used
#
# *   psutil.virtual_memory() --> returns RAM memory %  and RAM used(GB)
#
# *   In the following 9 common libraries we did use some basic codes to use those modules and found out how much time does that take to complete execution and noted thier memory usage and visualized them using graphs.
# *   In every graph memory usage andtime taken is plotted
#
#
# *   NOTE:
#  1.  business-financial-data-june-2022-quarter-csv.csv
#
#  2. download (1).jfif
#
#  3.   haarcascade_frontalface_default.xml
#  *  These are external files that used to evaluate memory usage of libraries

# %% [markdown]
# # Some Common ML libraries:
# ### 1.Numpy ✅
# ### 2.Scipy ✅
# ### 3.Pandas ✅
# ### 4.matplotlib ✅
# ### 5.seaborn ✅
# ### 6.Keras ✅
# ### 7.Tensorflow ✅
# ### 8.Scikit-learn✅
# ### 9.OPENCV ✅

# %% [markdown]
# * Traced Memroy-->🔴
# * Virtual Memory-->🟢
# * Time_elapsed-->🔵
#
# In graphs We use these colors were used to plot memory and time

# %%
time_library={} #time taken by every libray will added in this dictionary
memory_library={} #memory used by every libray will added in this dictionary
RAM_library={} #RAM usage by every libray will added in this dictionary

# %% [markdown]
# # NUMPY

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import time

def Numpy():
  list=[[1,23,45,67],[2,3,43,5]]
  print("Transpose of list:\n",np.array(list).transpose())
  print("Array1:\n",np.arange(0,101,20))
  print('Array2:\n',np.linspace(0,1,21))
  np.random.seed(101)
  print("Array3:\n",np.random.rand(2,3))

tracemalloc.start()
start = time.time()
Numpy()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['numpy_time_elapsed']=time['Time_elapsed']
memory_library['numpy_current_memory']=data['Current Memory Using']
RAM_library['numpy_RAM_USED(GB)']=data1['RAM Used (GB)']




print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function Numpy:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function Numpy:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# Transpose of list:
#  [[ 1  2]
#  [23  3]
#  [45 43]
#  [67  5]]
# Array1:
#  [  0  20  40  60  80 100]
# Array2:
#  [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]
# Array3:
#  [[0.51639863 0.57066759 0.02847423]
#  [0.17152166 0.68527698 0.83389686]]
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function Numpy: {'Current Memory Using': 6477, 'Peak Memory Used': 16819}
# Virtual Memory used by function Numpy: {'RAM memory % used': 18.3, 'RAM Used (GB)': 2.4302592}
# Time {'Time_elapsed': 0.006573200225830078}

# %% [markdown]
# In this library we used function 'Numpy' to use numpy module. Some Basic Operation

# %% [markdown]
# # SCIPY

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
from scipy import linalg
import time


def scipy():
  A = np.array([[1,2,3],[4,5,6],[7,8,8]])
  print("det is:",linalg.det(A))
  eigen_values, eigen_vectors = linalg.eig(A)
  print("Eigen Values:",eigen_values)
  print("Eigen Vectors",eigen_vectors)

tracemalloc.start()
start = time.time()
scipy()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['scipy_time_elapsed']=time['Time_elapsed']
memory_library['scipy_current_memory']=data['Current Memory Using']
RAM_library['scipy_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function scipy:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function scipy:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# det is: 3.0
# Eigen Values: [15.55528261+0.j -1.41940876+0.j -0.13587385+0.j]
# Eigen Vectors [[-0.24043423 -0.67468642  0.51853459]
#  [-0.54694322 -0.23391616 -0.78895962]
#  [-0.80190056  0.70005819  0.32964312]]
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function scipy: {'Current Memory Using': 10031, 'Peak Memory Used': 20373}
# Virtual Memory used by function scipy: {'RAM memory % used': 18.3, 'RAM Used (GB)': 2.430164992}
# Time {'Time_elapsed': 0.004641532897949219}

# %% [markdown]
# In this library we used function 'scipy' to use scipy module. Some Basic Operations

# %% [markdown]
# # PANDAS

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import time


def pandas():
  d=[20,21,22,19]
  n=['a','b','c','d']
  s=pd.Series(data=d,index=n)
  print("series1:\n",s)
  d=[23,24,22]
  n=['a','b','d']
  s1=pd.Series(data=d,index=n)
  print("\nseries2:\n",s1)
  print("\nAdding values of s and s1:\n",s.add(s1,fill_value=0))
  

tracemalloc.start()
start = time.time()
pandas()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['pandas_time_elapsed']=time['Time_elapsed']
memory_library['pandas_current_memory']=data['Current Memory Using']
RAM_library['pandas_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function pandas:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function pandas:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# series1:
#  a    20
# b    21
# c    22
# d    19
# dtype: int64
#
# series2:
#  a    23
# b    24
# d    22
# dtype: int64
#
# Adding values of s and s1:
#  a    43.0
# b    45.0
# c    22.0
# d    41.0
# dtype: float64
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function pandas: {'Current Memory Using': 10871, 'Peak Memory Used': 21213}
# Virtual Memory used by function pandas: {'RAM memory % used': 18.3, 'RAM Used (GB)': 2.43044352}
# Time {'Time_elapsed': 0.0057621002197265625}

# %% [markdown]
# In this library we used function 'pandas' to use pandas module.
# Operations are creating two small series using pandas and
# adding them

# %% [markdown]
# # MATPLOTLIB

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import time


def matplotlib():
  a = [1, 2, 3, 4, 5]
  b = [0, 0.6, 0.2, 15, 10, 8, 16, 21]
  plt.plot(a)
  plt.plot(b, "or")
  plt.plot(list(range(0, 22, 3)))
  plt.xlabel('Day ->')
  plt.ylabel('Temp ->')
  c = [4, 2, 6, 8, 3, 20, 13, 15]
  plt.plot(c, label = '4th Rep')
  ax = plt.gca()
  ax.spines['right'].set_visible(False)
  ax.spines['top'].set_visible(False)
  ax.spines['left'].set_bounds(-3, 40)
  plt.xticks(list(range(-3, 10)))
  plt.yticks(list(range(-3, 20, 3)))
  ax.legend(['1st Rep', '2nd Rep', '3rd Rep', '4th Rep'])
  plt.annotate('Temperature V / s Days', xy = (1.01, -2.15))
  plt.title('All Features Discussed')
  plt.show()

  

tracemalloc.start()
start = time.time()
matplotlib()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['matplotlib_time_elapsed']=time['Time_elapsed']
memory_library['matplotlib_current_memory']=data['Current Memory Using']
RAM_library['matplotlib_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function matplotlib:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function matplotlib:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function matplotlib: {'Current Memory Using': 939515, 'Peak Memory Used': 1024225}
# Virtual Memory used by function matplotlib: {'RAM memory % used': 18.1, 'RAM Used (GB)': 2.411061248}
# Time {'Time_elapsed': 0.2110140323638916}

# %% [markdown]
# In this library we used function 'matplotlib' to use matplotlib module. Some Basic Operations
# Tried to plot temperature vs days using matplotlib

# %% [markdown]
# # SEABORN

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import seaborn as sns
import time


def seaborn():
  data = sns.load_dataset("iris")
  sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  plt.xlim(5)
  plt.show()

  

tracemalloc.start()
start = time.time()
seaborn()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['seaborn_time_elapsed']=time['Time_elapsed']
memory_library['seaborn_current_memory']=data['Current Memory Using']
RAM_library['seaborn_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function seaborn:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function seaborn:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function seaborn: {'Current Memory Using': 806224, 'Peak Memory Used': 962092}
# Virtual Memory used by function seaborn: {'RAM memory % used': 18.2, 'RAM Used (GB)': 2.417614848}
# Time {'Time_elapsed': 1.1469991207122803}

# %% [markdown]
# In this library we used function 'seaborn' to use seaborn module.using seaborn loaded a datafile named iris and using columns in that data file created a lineplot

# %% [markdown]
# # KERAS

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
import time


def keras(): 
  visible = Input(shape=(10,))
  hidden = Dense(2)(visible)
  model = Model(inputs=visible, outputs=hidden)
  print("Executed")


tracemalloc.start()
start = time.time()
keras()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['keras_time_elapsed']=time['Time_elapsed']
memory_library['keras_current_memory']=data['Current Memory Using']
RAM_library['keras_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function keras:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function keras:",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# Executed
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function keras: {'Current Memory Using': 53583, 'Peak Memory Used': 63738}
# Virtual Memory used by function keras: {'RAM memory % used': 18.2, 'RAM Used (GB)': 2.42016256}
# Time {'Time_elapsed': 0.01736140251159668}

# %% [markdown]
# In this library we used function 'keras' to use keras module.
# Using Keras created basic input layer and output layer

# %% [markdown]
# #TENSORFLOW

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import tensorflow as tf
import time


def tensor():
  image=plt.imread('/content/download (1).jfif')
  image=tf.constant(image)
  image=tf.image.convert_image_dtype(image,tf.float32)
  image=tf.image.resize(image,(244,244))
  print(image[0][:2])

  

tracemalloc.start()
start = time.time()
tensor()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['Tensorflow_time_elapsed']=time['Time_elapsed']
memory_library['Tensorflow_current_memory']=data['Current Memory Using']
RAM_library['Tensorflow_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function tensor:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function tensor",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# tf.Tensor(
# [[0.7137255  0.8745099  0.95294124]
#  [0.7161283  0.87691265 0.955344  ]], shape=(2, 3), dtype=float32)
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function tensor: {'Current Memory Using': 7294, 'Peak Memory Used': 134729}
# Virtual Memory used by function tensor {'RAM memory % used': 18.2, 'RAM Used (GB)': 2.42427904}
# Time {'Time_elapsed': 0.007356166839599609}

# %% [markdown]
# In this library we used function 'tensor' to use tensorflow module.Here used tensorflow to create tensors from image
#
#
# In here we used an external file(image:-download (1).jfif) to find tensors

# %% [markdown]
# # SCIKIT-LEARN

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import numpy as np
import time

def sklearn(example):
  from sklearn.model_selection import train_test_split
  x=example.drop(['Period'],axis=1)
  y=example['Period']
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
  print("Train test split Was Successful")

tracemalloc.start()
start = time.time()
example_csv=pd.read_csv("/content/business-financial-data-june-2022-quarter-csv.csv",on_bad_lines='skip')
sklearn(example_csv)
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['sklearn_time_elapsed']=time['Time_elapsed']
memory_library['sklearn_current_memory']=data['Current Memory Using']
RAM_library['sklearn_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function tensor:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function tensor",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# Train test split Was Successful
#
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function tensor: {'Current Memory Using': 757845, 'Peak Memory Used': 2194558}
# Virtual Memory used by function tensor {'RAM memory % used': 18.3, 'RAM Used (GB)': 2.435432448}
# Time {'Time_elapsed': 0.13525152206420898}

# %% [markdown]
# In this library we used function 'sklearn' to use sklearn module.Here used sklearn to split data into train and test sets using train_test_split
#
#
#
# External file(business-financial-data-june-2022-quarter-csv.csv) to split data into train and test

# %% [markdown]
# # OPENCV

# %%
import tracemalloc
import numpy as np
import matplotlib.pyplot as plt
import psutil
import pandas as pd
import time
import cv2
from google.colab.patches import cv2_imshow


def opencv():
  face_cascade=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml") #Note the change

  img = cv2.imread("/content/download (1).jfif")
  gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

  faces=face_cascade.detectMultiScale(gray_img, scaleFactor=1.05,minNeighbors=5)

  for x, y, w, h in faces:
    img=cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)

  cv2_imshow(img)
  cv2.waitKey(0)
  cv2.destroyAllWindows()
  

tracemalloc.start()
start = time.time()
opencv()
tupl=(tracemalloc.get_traced_memory()) #he output is given in form of (current, peak),i.e, current memory is the memory the code is currently using and peak memory is the maximum space the program used while executing.
tracemalloc.stop()
end = time.time()

data={
    'Current Memory Using':tupl[0],
    'Peak Memory Used':tupl[1]}
data1={
    'RAM memory % used':psutil.virtual_memory()[2],
    'RAM Used (GB)':psutil.virtual_memory()[3]/1000000000
}
time={
    'Time_elapsed':end-start
}

time_library['opencv_time_elapsed']=time['Time_elapsed']
memory_library['opencv_current_memory']=data['Current Memory Using']
RAM_library['opencv_RAM_USED(GB)']=data1['RAM Used (GB)']

print("\n----------------------------------------------------------------------------------------------\n")
print("Traced Memory used by function opencv:",data)

items = list(data.keys())
values = list(data.values())

items1=list(data1.keys())
values1=list(data1.values())

items2=list(time.keys())
values2=list(time.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by function opencv",data1)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');

print("Time",time)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# <PIL.Image.Image image mode=RGB size=181x121 at 0x7F6AD4B16A90>
# ----------------------------------------------------------------------------------------------
#
# Traced Memory used by function opencv: {'Current Memory Using': 5490, 'Peak Memory Used': 290680}
# Virtual Memory used by function opencv {'RAM memory % used': 18.0, 'RAM Used (GB)': 2.405904384}
# Time {'Time_elapsed': 0.08046627044677734}

# %% [markdown]
# In this library we used function 'opencv' to use cv2 module.Here used cv2 to detect face in a image
#
#
#
# External File used download (1).jfif

# %% [markdown]
# #Comparing Libraries Time and memory usage
# and
# ####colab crash

# %%
time_library
# Out:
# {'numpy_time_elapsed': 0.006573200225830078,
#  'scipy_time_elapsed': 0.004641532897949219,
#  'pandas_time_elapsed': 0.0057621002197265625,
#  'matplotlib_time_elapsed': 0.2110140323638916,
#  'seaborn_time_elapsed': 1.1469991207122803,
#  'keras_time_elapsed': 0.01736140251159668,
#  'Tensorflow_time_elapsed': 0.007356166839599609,
#  'sklearn_time_elapsed': 0.13525152206420898,
#  'opencv_time_elapsed': 0.08046627044677734}

# %%
memory_library
# Out:
# {'numpy_current_memory': 6477,
#  'scipy_current_memory': 10031,
#  'pandas_current_memory': 10871,
#  'matplotlib_current_memory': 939515,
#  'seaborn_current_memory': 806224,
#  'keras_current_memory': 53583,
#  'Tensorflow_current_memory': 7294,
#  'sklearn_current_memory': 757845,
#  'opencv_current_memory': 5490}

# %%
RAM_library
# Out:
# {'numpy_RAM_USED(GB)': 2.4302592,
#  'scipy_RAM_USED(GB)': 2.430164992,
#  'pandas_RAM_USED(GB)': 2.43044352,
#  'matplotlib_RAM_USED(GB)': 2.411061248,
#  'seaborn_RAM_USED(GB)': 2.417614848,
#  'keras_RAM_USED(GB)': 2.42016256,
#  'Tensorflow_RAM_USED(GB)': 2.42427904,
#  'sklearn_RAM_USED(GB)': 2.435432448,
#  'opencv_RAM_USED(GB)': 2.405904384}

# %%
print("Traced Memory used by libraries:",memory_library)
items = list(memory_library.keys())
values = list(memory_library.values())

items1=list(RAM_library.keys())
values1=list(RAM_library.values())

items2=list(time_library.keys())
values2=list(time_library.values())

plt.subplot(1, 3, 1)
plt.bar(items, values, color='red');
plt.xticks(rotation=90);
plt.title('Traced Memory');

print("Virtual Memory used by libraries",RAM_library)
plt.subplot(1, 3, 2)
plt.bar(items1, values1, color='green');
plt.xticks(rotation=90);
plt.title('Virtual Memory');


print("Time taken by libraries",time_library)
plt.subplot(1,3,3)
plt.bar(items2,values2,color='skyblue');
plt.xticks(rotation=90)
plt.title('time');
# Out:
# Traced Memory used by libraries: {'numpy_current_memory': 6477, 'scipy_current_memory': 10031, 'pandas_current_memory': 10871, 'matplotlib_current_memory': 939515, 'seaborn_current_memory': 806224, 'keras_current_memory': 53583, 'Tensorflow_current_memory': 7294, 'sklearn_current_memory': 757845, 'opencv_current_memory': 5490}
# Virtual Memory used by libraries {'numpy_RAM_USED(GB)': 2.4302592, 'scipy_RAM_USED(GB)': 2.430164992, 'pandas_RAM_USED(GB)': 2.43044352, 'matplotlib_RAM_USED(GB)': 2.411061248, 'seaborn_RAM_USED(GB)': 2.417614848, 'keras_RAM_USED(GB)': 2.42016256, 'Tensorflow_RAM_USED(GB)': 2.42427904, 'sklearn_RAM_USED(GB)': 2.435432448, 'opencv_RAM_USED(GB)': 2.405904384}
# ...

# %% [markdown]
# *  **Tensorflow** library took less time compared to all other libraries where as **seaborn** library took more time
#
# * **OPENCV** library used less RAM than any other library
#   **sklearn** library used more RAM than any other library
# * **matplot** library using currently more memory than any other library.**opencv** using less current memory
#
#
# NOTE(Must Read): These values can change based the function or tasks that we do using these libraries. These execution times are based on some small operations using those libraries.
#
# ->these values will change if we execute them again this time some other libraries will be more than other libraries

# %% [markdown]
# #### COLAB CRASH

# %% [markdown]
# colab usaully crashes
# 1. when the notebook if a system is kept idle for more than 30 minutes or
# 2. that code written is exhausting all the resources that are provided for free by Google Colab or
# 3. Main disadvantge of google colab is Limited Space & Time.If code written leads to less space(that is lack of RAM) or more time then colab crashes

# %% [markdown]
# -->We can leave notebook more time(to train our model or to predict our model) by using following steps:-
# * User need to open the Chrome DevOps tool by pressing F12 or Ctrl+Shift+I to open inspector view and input the code mentioned below on the JavaScript code:
#
# ```
# function KeepClicking(){
#     console.log("Clicking");
#     document.querySelector('colab-toolbar-button#connect').click();
#     }
# setInterval(KeepClicking,60000)
# ```
# -->using GPU sometimes crashes more than using TPU. So avoid using GPU if you are not utilizing the GPU ,recommend switching to a standard runtime.
#
# -->if using large data prefer removing useless data to reduce time if large data it takes time to train the model on data which will eventually leads to crash.
#
# --> to know more about crashes go to runtime -> to runtime logs check message column
